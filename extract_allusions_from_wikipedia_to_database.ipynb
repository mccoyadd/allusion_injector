# %% [markdown]
# # Mining Wikipedia for Semantic Relations
#
# I define some functions to extract some semantic relations from Wikipedia text.  Specifically, they are relations that could be useful for crafting "automatic allusions"---i.e., given a `target word` such as `"multitudinous"`, return a snippet of text containing an old proper noun, such as `"as Ashurbanipal's army"`.

# %% [markdown]
# ## Mining ⛏️

# %% [markdown]
# ### Helper Functions

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
def test_contiguous(numbers):
    """
    just make sure that ints are contiguous
    useful for making sure a span of text isn't missing any words
    """
    for en,n in enumerate(numbers[:-1]):
        if n+1!=numbers[en+1]:
            return False
    return True

print(test_contiguous([123,124,125,126]))
print(test_contiguous([123,20]))
# Out:
# True
# False

# %%
def get_chunk(word,tempspacy):
    """
    get all ancestors of a word
    exclude bits that are connected by appos dependency
    """
    descendants = [i for i in tempspacy if (word.is_ancestor(i) or i==word)]
    to_ban = [i for i in descendants if (i.dep_ in ["appos"] and i!=word)]
    descendants_valid = [i for i in descendants if i not in to_ban]
    descendants_valid = [i for i in descendants_valid if not any([banned.is_ancestor(i) for banned in to_ban])]
    return descendants_valid

s = "Moatt of Carthage, a wise king, is very tired."
sp = nlp(s)
print(sp[0])
get_chunk(sp[0],sp)
# Out:
# Moatt
# [Moatt, of, Carthage, ,]

# %%
def rclip(fragment,bad_ending_pos=["PUNCT","SPACE"]):#ok_ending_pos=["NOUN","PROPN"]):
    """
    remove everything from the right of a spacy sequence if doesn't end correctly
    """
    while len(fragment)>0 and (fragment[-1].pos_ in bad_ending_pos and fragment[-1].text!=")"):
            fragment.pop()
    return fragment

# %%
rclip(get_chunk(sp[0],sp))
# Out:
# [Moatt, of, Carthage]

# %% [markdown]
# ### Functions for Mining Relations from Text Parsed with `spaCy`

# %%
def noun_of_nounphrase(tempspacy):
    """
    """
    to_return = []
    for t in tempspacy:
        if t.head.text.lower()=="of" and t.pos_ in ["NOUN","PROPN"]:
            fragment = rclip([i for i in tempspacy if (t.head.is_ancestor(i))])
            fragment_pos = [i.pos_ for i in fragment]
            fragment_indices = [i.i for i in fragment]
            if test_contiguous(fragment_indices):
                if "PROPN" in fragment_pos:
                    to_return.append({
                        "type":"of",
                        "target":str(t.head.head).lower(),
                        #"target_original":str(t.head.head),
                        "other_words":"|".join([child.text.lower() for child in t.head.head.children if child.dep_ in ['amod',"conj","advmod"]]),
                        "allusion":"of "+str(tempspacy[fragment_indices[0]:fragment_indices[-1]+1]),
                        "allusion2":None,
                        "target_pos":t.head.head.pos_,

                    })
    return to_return

noun_of_nounphrase(nlp("Beyond the old cat's stinky legs and ugly face.  The semi-ugly library of the cat of Alexandria.  And there was a Library of Alexandria. The cat's beautiful felt. A ball of yarn. The Shining Scales of Agoatus."))
# Out:
# [{'type': 'of',
#   'target': 'library',
#   'other_words': 'semi|-|ugly',
#   'allusion': 'of the cat of Alexandria',
#   'allusion2': None,
#   'target_pos': 'NOUN'},
#  {'type': 'of',
#   'target': 'cat',
#   'other_words': '',
#   'allusion': 'of Alexandria',
#   'allusion2': None,
#   'target_pos': 'NOUN'},
#  {'type': 'of',
#   'target': 'library',
#   'other_words': '',
#   'allusion': 'of Alexandria',
#   'allusion2': None,
#   'target_pos': 'PROPN'},
#  {'type': 'of',
#   'target': 'scales',
#   'other_words': 'shining',
#   'allusion': 'of Agoatus',
#   'allusion2': None,
#   'target_pos': 'PROPN'}]

# %%
def verb2np(tempspacy):
    to_return = []
    for t in tempspacy:
        if t.dep_=="nsubj":
            subtree = list(t.head.subtree)
            span = tempspacy[subtree[0].i:subtree[-1].i+1]
            if span[0].dep_=="mark":
                span = tempspacy[subtree[1].i:subtree[-1].i+1]
            fragment = [i for i in tempspacy if (t.is_ancestor(i) or i==t)]
            fragment_pos = [i.pos_ for i in fragment]
            fragment_indices = [i.i for i in fragment]
            if test_contiguous(fragment_indices):
                if "PROPN" in fragment_pos:
                    if t.head.lemma_ not in ["be"]: # boring
                        to_return.append({"type":"v2np",
                                          "target":t.head.lemma_,
                                          "other_words":"|".join([child.lemma_ for child in t.head.children if child.dep_ in ["dobj","conj","advmod","prt"]]),
                                          "allusion":str(span),
                                          "allusion2":str(tempspacy[fragment_indices[0]:fragment_indices[-1]+1]),
                                          "target_pos":t.head.pos_,
                                         })
    return to_return

verb2np(nlp("I have heard that Ashurbanurpal hurt my friend. I have heard a rumor that Ashurbanipal's army first advanced south and secured the city of Der, and there were people there"))
# Out:
# [{'type': 'v2np',
#   'target': 'hurt',
#   'other_words': 'friend',
#   'allusion': 'Ashurbanurpal hurt my friend',
#   'allusion2': 'Ashurbanurpal',
#   'target_pos': 'VERB'},
#  {'type': 'v2np',
#   'target': 'advance',
#   'other_words': 'first|south|secure',
#   'allusion': "Ashurbanipal's army first advanced south and secured the city of Der",
#   'allusion2': "Ashurbanipal's army",
#   'target_pos': 'VERB'}]

# %%
from collections import defaultdict

def adj_to_noun_phrase(tempspacy):
    to_return = []
    for t in tempspacy:
        if t.dep_=="amod":
            if "neg" not in [c.dep_ for c in t.children]:
                if (t.head.pos_=="NOUN"):
                    #fragment = rclip([i for i in tempspacy if (t.head.is_ancestor(i) or i==t.head)])
                    fragment = rclip(get_chunk(t.head,tempspacy))
                    fragment_pos = [i.pos_ for i in fragment]
                    fragment_indices = [i.i for i in fragment]
                    if test_contiguous(fragment_indices):
                        if "PROPN" in fragment_pos:
                            to_return.append({
                                "target":str(t).lower(),
                                "allusion":str(tempspacy[fragment_indices[0]:fragment_indices[-1]+1]),
                                "type":"adj2np",
                                "allusion2":None,
                                "other_words":None,
                                "target_pos":"ADJ",
                            })
    return to_return
        
adj_to_noun_phrase(nlp("I saw the rebellious, stinky friends of Azerooit and his merciless ilk, a bad team.  And I saw the shining scales of Aotis."))
# Out:
# [{'target': 'rebellious',
#   'allusion': 'the rebellious, stinky friends of Azerooit and his merciless ilk',
#   'type': 'adj2np',
#   'allusion2': None,
#   'other_words': None,
#   'target_pos': 'ADJ'},
#  {'target': 'stinky',
#   'allusion': 'the rebellious, stinky friends of Azerooit and his merciless ilk',
#   'type': 'adj2np',
#   'allusion2': None,
#   'other_words': None,
#   'target_pos': 'ADJ'},
#  {'target': 'shining',
#   'allusion': 'the shining scales of Aotis',
#   'type': 'adj2np',
#   'allusion2': None,
#   'other_words': None,
#   'target_pos': 'ADJ'}]

# %%
def attr_or_acomp_relation(tempspacy):
    to_return = []
    for t in tempspacy: 
        if (t.dep_=="nsubj" and t.head.pos_=="AUX"):  ## looking for nouns that are in nsubj relationship to aux verb
            if "neg" not in [i.dep_ for i in t.head.children]: ## exclude negatives
                attrs = [ch for ch in [tok for tok in tempspacy if tok.head==t.head] if ch.dep_ in ["attr","acomp"]]
                if attrs!=[]: ## if there is at least 1 attr
                    attr = attrs[0] ## just deal with the 0th one
                    attr_or_acomp = attr.dep_
                    ## get the noun ph
                    #np_fragment = [i for i in tempspacy if (t.is_ancestor(i) or i==t)]
                    np_fragment = rclip(get_chunk(t,tempspacy))
                    np_fragment_pos = [i.pos_ for i in np_fragment]
                    np_fragment_indices = [i.i for i in np_fragment]
                    noun_phrase = str(tempspacy[np_fragment_indices[0]:np_fragment_indices[-1]+1])
                    if "PROPN" in np_fragment_pos:     
                        ## get attr phrase
                        #attr_fragment = [i for i in tempspacy if (attr.is_ancestor(i) or i==attr)]
                        attr_fragment = rclip((get_chunk(attr,tempspacy)))
                        attr_fragment_indices = [i.i for i in attr_fragment]
                        attr_phrase = str(tempspacy[attr_fragment_indices[0]:attr_fragment_indices[-1]+1])
                        ## get attr phrase simple
                        valid_deps = ["det","amod"]
                        simple_fragment = [i for i in tempspacy if ((i.head==attr and i.dep_ in valid_deps) or i==attr)]
                        simple_fragment_indices = [i.i for i in simple_fragment]
                        simple_phrase = str(tempspacy[simple_fragment_indices[0]:simple_fragment_indices[-1]+1])
                        if test_contiguous(np_fragment_indices) and test_contiguous(attr_fragment_indices):
                            for n in [w for w in simple_fragment if w.pos_ in ["NOUN","ADJ"]]:
                                to_return.append({
                                    "type":attr_or_acomp,
                                    "allusion":noun_phrase,
                                    "target":n.lemma_,
                                    "allusion2":simple_phrase,
                                    "other_words":"|".join([child.text.lower() for child in n.children if child.dep_ in ['amod']]),
                                    "target_pos":n.pos_
                                })
    return to_return

# %%
attr_or_acomp_relation(nlp("John is uick to speak. A mind is a terrible thing to puree. The feet of the Big King were a simple nomadic people who moved through the earth and ate things, and the Dull Forest was a stupid place where old people went. Mausoolus was a wise king of bitter sadness, a good person.  John was a big lawyer.  Mausoolus of Xeria was going to the store."))
# Out:
# [{'type': 'acomp',
#   'allusion': 'John',
#   'target': 'uick',
#   'allusion2': 'uick',
#   'other_words': '',
#   'target_pos': 'ADJ'},
#  {'type': 'attr',
#   'allusion': 'The feet of the Big King',
#   'target': 'simple',
#   'allusion2': 'a simple nomadic people',
#   'other_words': '',
#   'target_pos': 'ADJ'},
#  {'type': 'attr',
#   'allusion': 'The feet of the Big King',
#   'target': 'nomadic',
#   'allusion2': 'a simple nomadic people',
#   'other_words': '',
#   'target_pos': 'ADJ'},
#  {'type': 'attr',
#   'allusion': 'The feet of the Big King',
#   'target': 'people',
#   'allusion2': 'a simple nomadic people',
#   'other_words': 'simple|nomadic',
#   'target_pos': 'NOUN'},
#  {'type': 'attr',
#   'allusion': 'the Dull Forest',
#   'target': 'stupid',
#   'allusion2': 'a stupid place',
#   'other_words': '',
#   'target_pos': 'ADJ'},
#  {'type': 'attr',
#   'allusion': 'the Dull Forest',
#   'target': 'place',
#   'allusion2': 'a stupid place',
#   'other_words': 'stupid',
#   'target_pos': 'NOUN'},
#  {'type': 'attr',
#   'allusion': 'Mausoolus',
#   'target': 'wise',
#   'allusion2': 'a wise king',
#   'other_words': '',
#   'target_pos': 'ADJ'},
#  {'type': 'attr',
#   'allusion': 'Mausoolus',
#   'target': 'king',
#   'allusion2': 'a wise king',
#   'other_words': 'wise',
#   'target_pos': 'NOUN'},
#  {'type': 'attr',
#   'allusion': 'John',
#   'target': 'big',
#   'allusion2': 'a big lawyer',
#   'other_words': '',
#   'target_pos': 'ADJ'},
#  {'type': 'attr',
#   'allusion': 'John',
#   'target': 'lawyer',
#   'allusion2': 'a big lawyer',
#   'other_words': 'big',
#   'target_pos': 'NOUN'}]

# %%
def appos_relation(tempspacy):
    to_return = []
    for t in tempspacy:
        if t.dep_=="appos":
            appos_fragment = get_chunk(t,tempspacy) ##[i for i in tempspacy if (t.is_ancestor(i) or i==t)]
            appos_fragment_indices = [i.i for i in appos_fragment]
            appos_phrase = str(tempspacy[appos_fragment_indices[0]:appos_fragment_indices[-1]+1])
            ## get the noun ph
            noun_or_proper_noun = t.head
            valid_deps = ['compound']
            np_fragment = rclip(get_chunk(noun_or_proper_noun,tempspacy))#
            np_fragment_pos = [i.pos_ for i in np_fragment]
            np_fragment_indices = [i.i for i in np_fragment]
            noun_phrase = str(tempspacy[np_fragment_indices[0]:np_fragment_indices[-1]+1])
            if "PROPN" in np_fragment_pos:    
                if test_contiguous(np_fragment_indices) and test_contiguous(appos_fragment_indices):
                    for n in [w for w in appos_fragment if w.pos_ in ["NOUN","ADJ"]]:
                        to_return.append({
                            "type":"appos",
                            "allusion":noun_phrase,
                            "allusion2":appos_phrase,
                            "target":n.lemma_,
                            "other_words":"|".join([w.lemma_ for w in appos_fragment if w.pos_=="ADJ"]),
                            "target_pos":n.pos_,
                        })                   
    return to_return

appos_relation(nlp(" King Mausaillus of Carthage, a wise and fat king, is my friend. Mausoolus was going to the store. The old King Mausoolaic of Wales, a wise and smelly king, is my friend."))#ppos_relation(nlp("King Mausaillus of Carthage, a wise person, is my friend. Mausoolus was going to the store. The old King Mausoolaic of Wales, a wise king, is my friend."))
# Out:
# [{'type': 'appos',
#   'allusion': ' King Mausaillus of Carthage',
#   'allusion2': 'a wise and fat king',
#   'target': 'wise',
#   'other_words': 'wise|fat',
#   'target_pos': 'ADJ'},
#  {'type': 'appos',
#   'allusion': ' King Mausaillus of Carthage',
#   'allusion2': 'a wise and fat king',
#   'target': 'fat',
#   'other_words': 'wise|fat',
#   'target_pos': 'ADJ'},
#  {'type': 'appos',
#   'allusion': ' King Mausaillus of Carthage',
#   'allusion2': 'a wise and fat king',
#   'target': 'king',
#   'other_words': 'wise|fat',
#   'target_pos': 'NOUN'},
#  {'type': 'appos',
#   'allusion': 'The old King Mausoolaic of Wales',
#   'allusion2': 'a wise and smelly king',
#   'target': 'wise',
#   'other_words': 'wise|smelly',
#   'target_pos': 'ADJ'},
#  {'type': 'appos',
#   'allusion': 'The old King Mausoolaic of Wales',
#   'allusion2': 'a wise and smelly king',
#   'target': 'smelly',
#   'other_words': 'wise|smelly',
#   'target_pos': 'ADJ'},
#  {'type': 'appos',
#   'allusion': 'The old King Mausoolaic of Wales',
#   'allusion2': 'a wise and smelly king',
#   'target': 'king',
#   'other_words': 'wise|smelly',
#   'target_pos': 'NOUN'}]

# %%
mining_funcs = [
    noun_of_nounphrase,
    verb2np,
    adj_to_noun_phrase,
    attr_or_acomp_relation,
    appos_relation,
]

# %% [markdown]
# ## Wikipedia Article Tester
#
# I want to focus on things from Wikipedia that are old.  I will use some gnarly regexes to test whether some section of a Wikipedia text contains references to dates in the 19th century or prior and none from later.

# %%
import re

# %%
old_stuff_regex = r'\b(?:in|from|c\.|year) ?(?:late|early)? ?(?:\d{3}|1[0-8]\d\d)\b|\d+ b.?c.?|\b(?:[1-9]|1[0-9])(?:st|nd|th) century|\b(?!tw)[a-z]+(?:th|nd|st) century|\b\d{3,4}\b ?- ?\b(?:\d{3}|1[0-8]\d\d)\b|\((?:\d{3}|1[0-8]\d\d)\b\)|(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|spring|summer|fall|winter).+ (?:of  |, )?(?:\d{3}|1[0-8]\d\d)\b'

# %%
new_stuff_regex = r'\b(?:in|from|c\.|year) ?(?:late|early)? ?(?:19|2\d)\d\d\b|\d+ b.?c.?|\b2[0-9](?:st|nd|th) century|\btw[a-z-]+(?:th|nd|st) century|\b\d{3,4}\b ?- ?\b(?:\d{3}|1[0-8]\d\d)\b|\((?:19|2\d)\d\d\b\)|(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|spring|summer|fall|winter).+ (?:of  |, )?(?:19|2\d)\d\d\b'

# %%
test_string = """
(c. 334 – c. 2602 BC)
18th century
20th century
2nd century
first century
ninth century
nineteeth century
twentieth century
from 1923
from 1520
(119)
(1953)
(1834)
1995
the year 1895
in late 234
in late 1943
in early 1734

June, 1924
July of 2345
June, 1892
June, 234l234

spring of 1233

c. 234
c.234 
c. 1234
1523-1934
234
1523453245
"""

# %%
re.findall(old_stuff_regex,test_string)
# Out:
# ['c. 334',
#  '18th century',
#  '2nd century',
#  'first century',
#  'ninth century',
#  'nineteeth century',
#  'from 1520',
#  '(119)',
#  '(1834)',
#  'year 1895',
#  'in late 234',
#  'in early 1734',
#  'June, 1892',
#  'spring of 1233',
#  'c. 234',
#  'c.234',
#  'c. 1234']

# %%
re.findall(new_stuff_regex,test_string)
# Out:
# ['c. 2602',
#  '20th century',
#  'twentieth century',
#  'from 1923',
#  '(1953)',
#  'in late 1943',
#  'June, 1924',
#  'July of 2345']

# %%
def text_time_of_text(text):
    olds = re.findall(old_stuff_regex,text,flags=re.I)
    news = re.findall(new_stuff_regex,text,flags=re.I)
#     print(olds)
#     print(news)
    if len(olds)>0:
        if len(news)==0:
            return True
    return False

# %%
text_time_of_text("in the 2nd CENTuRY ")
# Out:
# True

# %%
text_time_of_text("in 1923 and the 2nd century")
# Out:
# False

# %% [markdown]
# ***

# %%
import re

def clean_wiki_text(text):
    text = re.sub(r"\'\'",'',text) ## links
    text = re.sub(r"poly[ \d]+","",text) ## ?
    text = re.sub(r"=+[^=]+=+\n"," ",text) ## section headings
    text = re.sub(r"\|alt=.+\n"," ",text) ## alt text
    text = text.rstrip(r"\n")
    return text

clean_wiki_text('====Union military strategy====\nLincoln took executive control of the war and shaped the Union military strategy.   |alt=Large group of people\n  sdfl;kasdf\n')
# Out:
# ' Lincoln took executive control of the war and shaped the Union military strategy.      sdfl;kasdf\n'

# %%
from gensim import utils

import json

# %%
# !rm wiki.db ## just re-initialize each time this notebook runs

# %%
import sqlite3
connection = sqlite3.connect("wiki.db")
cursor = connection.cursor()

# %%
cursor.execute("CREATE TABLE allusions (target TEXT, type TEXT, allusion TEXT, allusion2 TEXT, other_words TEXT, target_pos TEXT, entry TEXT, id NUMBER)")

# %%
def push_to_db(data):
    sql = "INSERT INTO allusions(target,type,allusion,allusion2,other_words,target_pos,entry,id) VALUES(?,?,?,?,?,?,?,?)"  
    for d in data:
        #print(d.keys())
        task = (d['target'],d['type'],d['allusion'],d['allusion2'],d['other_words'],d['target_pos'],d['entry'],d['id'])
        ## replace empty strings with None
        task = tuple(t if t!="" else None for t in task)
        print(task)
        cursor.execute(sql,task)
        connection.commit()
#         for k in d:
#             print(k,d[k])
            #task = (k[])
            #cur.execute(sql, task)

# %%
c=0
max_n = 10

idnum = 0

with utils.open('enwiki-latest.json.gz', 'rb') as f:
    for line in f:
        article = json.loads(line)
        for section_title, section_text in zip(article['section_titles'], article['section_texts']):
            text = section_text.strip()
            if text_time_of_text(text) and len(text)>300:              
                #print("Section title: %s" % section_title)
                text = clean_wiki_text(text)
                ok_sents = [s for s in text.split("\n\n") if len(s)>400]
                #print(ok_sents)
                for oks in ok_sents:
                    spacied = nlp(oks)
                    for func in mining_funcs:
                        #try:
                        results = func(spacied)
                        [r.update({"entry":article['title']}) for r in results] ## just update all the dicts
                        for r in results:
                            r.update({"id":idnum})
                            idnum+=1
                        push_to_db(results)
#                         except:
#                             pass
        c+=1
        if c>max_n:
            break
# Out:
# ('revolutionaries', 'of', 'of the 19th century such as William Godwin (1756–1836) and Wilhelm Weitling (1808–1871)', None, 'many', 'NOUN', 'Anarchism', 0)
# ('label', 'v2np', 'Various factions within the French Revolution labelled their opponents as anarchists, although few such accused shared many views with later anarchists.', 'Various factions within the French Revolution', 'opponent', 'VERB', 'Anarchism', 1)
# ('contribute', 'v2np', 'Many revolutionaries of the 19th century such as William Godwin (1756–1836) and Wilhelm Weitling (1808–1871) would contribute to the anarchist doctrines of the next generation but did not use anarchist or anarchism in describing themselves or their beliefs.', 'Many revolutionaries of the 19th century such as William Godwin (1756–1836) and Wilhelm Weitling (1808–1871)', 'use', 'VERB', 'Anarchism', 2)
# ('ancient', 'adj2np', 'the Ancient Greek anarkhia', None, None, 'ADJ', 'Anarchism', 3)
# ('various', 'adj2np', 'Various factions within the French Revolution', None, None, 'ADJ', 'Anarchism', 4)
# ('example', 'attr', 'Wilhelm Weitling', 'an example', None, 'NOUN', 'Anarchism', 5)
# ('wider', 'adj2np', 'wider adoption from ideologically disparate groups, including both the New Left and libertarian Marxists, who do not associate themselves with authoritarian socialists or a vanguard party, and extreme cultural liberals, who are primarily concerned with civil liberties', None, None, 'ADJ', 'Anarchism', 6)
# ('disparate', 'adj2np', 'ideologically disparate groups, including both the New Left and libertarian Marxists, who do not associate themselves with authoritarian socialists or a vanguard party, and extreme cultural liberals, who are primarily concerned with civil liberties', None, None, 'ADJ', 'Anarchism', 7)
# ('ancestor', 'of', 'of "A', None, 'earliest|certain', 'NOUN', 'A', 8)
# ('ancestor', 'of', 'of aleph', None, None, 'NOUN', 'A', 9)
# ('earliest', 'adj2np', 'The earliest certain ancestor of "A', None, None, 'ADJ', 'A', 10)
# ('certain', 'adj2np', 'The earliest certain ancestor of "A', None, None, 'ADJ', 'A', 11)
# ('aleph', 'attr', 'The earliest certain ancestor of "A', 'aleph', None, 'NOUN', 'A', 12)
# ('pictogram', 'attr', 'the ancestor of aleph', 'a pictogram', None, 'NOUN', 'A', 13)
# ('adopt', 'v2np', 'When the ancient Greeks adopted the alphabet', 'the ancient Greeks', 'when|alphabet', 'VERB', 'A', 14)
# ('that', 'v2np', 'the letter denoted in Phoenician and other Semitic languages, and', 'the letter denoted in Phoenician and other Semitic languages, and', None, 'SCONJ', 'A', 15)
# ('earliest', 'adj2np', 'the earliest Greek inscriptions after the Greek Dark Ages', None, None, 'ADJ', 'A', 16)
# ('greek', 'adj2np', 'the earliest Greek inscriptions after the Greek Dark Ages', None, None, 'ADJ', 'A', 17)
# ('forms', 'of', 'of the letter "A', None, 'many', 'NOUN', 'A', 18)
# ('examples', 'of', 'of different types of cursive, such as majuscule cursive, minuscule cursive, and semicursive minuscule', None, 'many|surviving', 'NOUN', 'A', 19)
# ('roman', 'adj2np', 'Roman times', None, None, 'ADJ', 'A', 20)
# ('many', 'adj2np', 'many surviving examples of different types of cursive, such as majuscule cursive, minuscule cursive, and semicursive minuscule', None, None, 'ADJ', 'A', 21)
# ('surviving', 'adj2np', 'many surviving examples of different types of cursive, such as majuscule cursive, minuscule cursive, and semicursive minuscule', None, None, 'ADJ', 'A', 22)
# ('different', 'adj2np', 'different types of cursive, such as majuscule cursive, minuscule cursive, and semicursive minuscule', None, None, 'ADJ', 'A', 23)
# ('end', 'of', 'of the Roman Empire (5th century AD)', None, None, 'NOUN', 'A', 24)
# ('variants', 'of', 'of the cursive minuscule developed through Western Europe', None, 'several', 'NOUN', 'A', 25)
# ('minuscule', 'of', 'of Italy', None, 'semicursive', 'NOUN', 'A', 26)
# ('majuscule', 'of', 'of Great Britain', None, 'insular', 'NOUN', 'A', 27)
# ('several', 'adj2np', 'several variants of the cursive minuscule developed through Western Europe', None, None, 'ADJ', 'A', 28)
# ('cursive', 'adj2np', 'the cursive minuscule developed through Western Europe', None, None, 'ADJ', 'A', 29)
# ('semicursive', 'adj2np', 'the semicursive minuscule of Italy', None, None, 'ADJ', 'A', 30)
# ('merovingian', 'adj2np', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', None, None, 'ADJ', 'A', 31)
# ('visigothic', 'adj2np', 'the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', None, None, 'ADJ', 'A', 32)
# ('insular', 'adj2np', 'the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', None, None, 'ADJ', 'A', 33)
# ('principal', 'attr', 'the Caroline script, which was very similar to the present-day form', 'the principal form', None, 'ADJ', 'A', 34)
# ('form', 'attr', 'the Caroline script, which was very similar to the present-day form', 'the principal form', 'principal', 'NOUN', 'A', 35)
# ('merovingian', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 36)
# ('script', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'NOUN', 'A', 37)
# ('visigothic', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 38)
# ('script', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'NOUN', 'A', 39)
# ('insular', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 40)
# ('anglo', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 41)
# ('irish', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 42)
# ('semi', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 43)
# ('-', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 44)
# ('uncial', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 45)
# ('anglo', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 46)
# ('saxon', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'ADJ', 'A', 47)
# ('majuscule', 'appos', 'the semicursive minuscule of Italy', 'the Merovingian script in France, the Visigothic script in Spain, and the Insular or Anglo-Irish semi-uncial or Anglo-Saxon majuscule of Great Britain', 'merovingian|visigothic|insular|anglo|irish|semi|-|uncial|anglo|saxon', 'NOUN', 'A', 48)
# ('see', 'v2np', 'Road sign in Ireland, showing the Irish "Latin alpha" form of "a" in lower and upper case forms.\n15th-century Italy saw the formation of the two main variants that are known today.', 'Road sign in Ireland, showing the Irish "Latin alpha" form of "a" in lower and upper case forms.\n', 'formation', 'VERB', 'A', 49)
# ('see', 'v2np', 'Road sign in Ireland, showing the Irish "Latin alpha" form of "a" in lower and upper case forms.\n15th-century Italy saw the formation of the two main variants that are known today.', '15th-century Italy', 'formation', 'VERB', 'A', 50)
# ('call', 'v2np', 'The Italic form, also called script a', 'The Italic form,', 'also|script', 'VERB', 'A', 51)
# ('italic', 'adj2np', 'the Italic and Roman forms', None, None, 'ADJ', 'A', 52)
# ('slaying', 'of', 'of the Trojan prince Hector', None, None, 'NOUN', 'Achilles', 53)
# ('gates', 'of', 'of Troy', None, None, 'NOUN', 'Achilles', 54)
# ('death', 'of', 'of Achilles', None, None, 'NOUN', 'Achilles', 55)
# ('end', 'of', 'of the Trojan War by Paris, who shot him with an arrow', None, None, 'NOUN', 'Achilles', 56)
# ('dip', 'v2np', "Later legends (beginning with Statius' unfinished epic Achilleid, written in the 1st century AD) state that Achilles was invulnerable in all of his body except for one heel, because when his mother Thetis dipped him in the river Styx as an infant", "Later legends (beginning with Statius' unfinished epic Achilleid, written in the 1st century AD) state that Achilles was invulnerable in all of his body except for one heel,", 'when|he|Styx', 'VERB', 'Achilles', 57)
# ('dip', 'v2np', "Later legends (beginning with Statius' unfinished epic Achilleid, written in the 1st century AD) state that Achilles was invulnerable in all of his body except for one heel, because when his mother Thetis dipped him in the river Styx as an infant", 'his mother Thetis', 'when|he|Styx', 'VERB', 'Achilles', 58)
# ('come', 'v2np', 'Alluding to these legends, the term "Achilles\' heel" has come to mean a point of weakness, especially in someone or something with an otherwise strong constitution.', 'the term "Achilles\' heel"', None, 'VERB', 'Achilles', 59)
# ('notable', 'adj2np', "Achilles' most notable feat during the Trojan War", None, None, 'ADJ', 'Achilles', 60)
# ('later', 'adj2np', "Later legends (beginning with Statius' unfinished epic Achilleid, written in the 1st century AD) state that Achilles was invulnerable in all of his body except for one heel", None, None, 'ADJ', 'Achilles', 61)
# ('slaying', 'attr', "Achilles' most notable feat during the Trojan War", 'the slaying', None, 'NOUN', 'Achilles', 62)
# ('invulnerable', 'acomp', 'Achilles', 'invulnerable', None, 'ADJ', 'Achilles', 63)
# ('name', 'of', 'of a female gladiator fighting an "Amazon', None, None, 'NOUN', 'Achilles', 64)
# ('attest', 'v2np', 'Linear B tablets attest to the personal name Achilleus in the forms a-ki-re-u and a-ki-re-we, the latter being the dative of the former.', 'Linear B tablets', 're|-', 'VERB', 'Achilles', 65)
# ('female', 'adj2np', 'a female gladiator fighting an "Amazon', None, None, 'ADJ', 'Achilles', 66)
# ('form', 'v2np', 'Achilles\' role as the hero of grief or distress forms an ironic juxtaposition with the conventional view of him as the hero of   ("glory", usually in war).', "Achilles' role as the hero of grief or distress", 'juxtaposition', 'VERB', 'Achilles', 67)
# ('people', 'appos', 'a proto-form *Akhí-lāu̯os', 'he who has the people distressed" or "he whose people have distress"', 'distressed', 'NOUN', 'Achilles', 68)
# ('distressed', 'appos', 'a proto-form *Akhí-lāu̯os', 'he who has the people distressed" or "he whose people have distress"', 'distressed', 'ADJ', 'Achilles', 69)
# ('people', 'appos', 'a proto-form *Akhí-lāu̯os', 'he who has the people distressed" or "he whose people have distress"', 'distressed', 'NOUN', 'Achilles', 70)
# ('distress', 'appos', 'a proto-form *Akhí-lāu̯os', 'he who has the people distressed" or "he whose people have distress"', 'distressed', 'NOUN', 'Achilles', 71)
# ('those', 'of', 'of river deities such as Acheron and Achelous', None, None, 'PRON', 'Achilles', 72)
# ('lead', 'v2np', "Achilles' descent from the Nereid Thetis and a similarity of his name with those of river deities such as Acheron and Achelous have led to speculations about his being an old water divinity .", "Achilles' descent from the Nereid Thetis and a similarity of his name with those of river deities such as Acheron and Achelous", None, 'VERB', 'Achilles', 73)
# ('suggest', 'v2np', 'Robert S. P. Beekes has suggested a Pre-Greek origin of the name, based among other things on the coexistence of -λλ- and -λ- in epic language, which may account for a palatalized phoneme /ly/ in the original language.', 'Robert S. P. Beekes', 'origin', 'VERB', 'Achilles', 74)
# ('son', 'of', 'of Thetis, a Nereid and daughter of The Old Man of the Sea, and Peleus, the king of the Myrmidons', None, None, 'NOUN', 'Achilles', 75)
# ('nereid', 'of', 'of The Old Man of the Sea', None, 'daughter|peleus', 'PROPN', 'Achilles', 76)
# ('man', 'of', 'of the Sea', None, None, 'PROPN', 'Achilles', 77)
# ('king', 'of', 'of the Myrmidons', None, None, 'NOUN', 'Achilles', 78)
# ('warned', 'of', 'of a prophecy (originally uttered by Themis, goddess of divine law)', None, None, 'VERB', 'Achilles', 79)
# ('bear', 'v2np', 'Thetis would bear a son greater than his father', 'Thetis', 'son', 'VERB', 'Achilles', 80)
# ('son', 'attr', 'Achilles', 'the son', None, 'NOUN', 'Achilles', 81)
# ('rival', 'attr', 'Zeus and Poseidon', 'rivals', None, 'NOUN', 'Achilles', 82)
# ('king', 'appos', 'Peleus', 'the king of the Myrmidons', None, 'NOUN', 'Achilles', 83)
# ('fore', 'appos', 'Prometheus', 'the fore-thinker', None, 'NOUN', 'Achilles', 84)
# ('thinker', 'appos', 'Prometheus', 'the fore-thinker', None, 'NOUN', 'Achilles', 85)
# ('advances', 'of', 'of Zeus', None, None, 'NOUN', 'Achilles', 86)
# ('daughter', 'of', 'of the sea-god Nereus', None, None, 'NOUN', 'Achilles', 87)
# ('advances', 'of', 'of Zeus', None, None, 'NOUN', 'Achilles', 88)
# ('allude', 'v2np', "There is a tale which offers an alternative version of these events: In the Argonautica (4.760) Zeus' sister and wife Hera alludes to Thetis' chaste resistance to the advances of Zeus, pointing out that Thetis was so loyal to Hera's marriage bond that she coolly rejected the father of gods.", "Zeus' sister and wife Hera", None, 'VERB', 'Achilles', 89)
# ('chaste', 'adj2np', "Thetis' chaste resistance to the advances of Zeus", None, None, 'ADJ', 'Achilles', 90)
# ('loyal', 'acomp', 'Thetis', 'loyal', None, 'ADJ', 'Achilles', 91)
# ('furious', 'acomp', 'Zeus', 'furious', None, 'ADJ', 'Achilles', 92)
# ('try', 'v2np', 'According to the Achilleid, written by Statius in the 1st century AD, and to non-surviving previous sources, when Achilles was born Thetis tried to make him immortal by dipping him in the river Styx', 'Thetis', None, 'VERB', 'Achilles', 93)
# ('anoint', 'v2np', 'In another version of this story, Thetis anointed the boy in ambrosia and put him on top of a fire in order to burn away the mortal parts of his body.', 'Thetis', 'boy|put', 'VERB', 'Achilles', 94)
# ('poems', 'of', "of the Epic Cycle which describe the hero's death (i.e. the Cypria, the Little Iliad by Lesches of Pyrrha, the Aithiopis and Iliou persis by Arctinus of Miletus", None, 'few|fragmentary', 'NOUN', 'Achilles', 95)
# ('lesches', 'of', 'of Pyrrha, the Aithiopis and Iliou persis by Arctinus of Miletus', None, None, 'PROPN', 'Achilles', 96)
# ('arctinus', 'of', 'of Miletus', None, None, 'PROPN', 'Achilles', 97)
# ('death', 'of', 'of Achilles, the arrow', None, None, 'NOUN', 'Achilles', 98)
# ('later', 'adj2np', 'the later vase paintings presenting the death of Achilles', None, None, 'ADJ', 'Achilles', 99)
# ('little', 'appos', 'i.e. the Cypria', 'the Little Iliad', 'little', 'ADJ', 'Achilles', 100)
# ('persis', 'appos', 'Pyrrha', 'the Aithiopis and Iliou persis by Arctinus of Miletus', None, 'NOUN', 'Achilles', 101)
# ('arrow', 'appos', 'Achilles', 'the arrow (', None, 'NOUN', 'Achilles', 102)
# ('book', 'of', 'of the New History', None, 'sixth', 'NOUN', 'Achilles', 103)
# ('body', 'of', 'of the Damysus, who was the fastest of all the giants', None, None, 'NOUN', 'Achilles', 104)
# ('burn', 'v2np', 'Thetis burned in a secret place the children she had by Peleus', 'Thetis', 'child', 'VERB', 'Achilles', 105)
# ('notice', 'v2np', 'Achilles, Peleus noticed,', 'Achilles, Peleus', None, 'VERB', 'Achilles', 106)
# ('exhume', 'v2np', "Later Chiron exhumed the body of the Damysus, who was the fastest of all the giants, removed the ankle, and incorporated it into Achilles' burnt foot.", 'Chiron', 'later|body|remove', 'VERB', 'Achilles', 107)
# ('sixth', 'adj2np', 'the sixth book of the New History by Ptolemy Hephaestion', None, None, 'ADJ', 'Achilles', 108)
# ('burnt', 'adj2np', "Achilles' burnt foot", None, None, 'ADJ', 'Achilles', 109)
# ('sixth', 'appos', 'Photius', 'the sixth book of the New History by Ptolemy Hephaestion', 'sixth', 'ADJ', 'Achilles', 110)
# ('book', 'appos', 'Photius', 'the sixth book of the New History by Ptolemy Hephaestion', 'sixth', 'NOUN', 'Achilles', 111)
# ('history', 'appos', 'Photius', 'the sixth book of the New History by Ptolemy Hephaestion', 'sixth', 'NOUN', 'Achilles', 112)
# ('name', 'of', 'of Thessaly\n* \'Aspetos\', "inimitable" or "vast", his name at Epirus', None, None, 'NOUN', 'Achilles', 113)
# ('town', 'of', 'of Achaia Phthiotis', None, None, 'NOUN', 'Achilles', 114)
# ('one', 'of', 'of the Nereids', None, None, 'NUM', 'Achilles', 115)
# ('pelide', 'v2np', '\'Ligyron\', his original name\n* \'Nereius\', from his mother Thetis, one of the Nereids\n* \'Pelides\', from his father, Peleus\n* \'Phthius\', from his birthplace, Phthia\n* \'Podarkes\', "swift-footed", due to the wings of Arke being attached to his feet.', 'Ligyron', None, 'NOUN', 'Achilles', 116)
# ('country', 'appos', 'Aemonia', 'a country which afterwards acquired the name of Thessaly\n* \'Aspetos\', "inimitable" or "vast",', 'inimitable|vast', 'NOUN', 'Achilles', 117)
# ('name', 'appos', 'Aemonia', 'a country which afterwards acquired the name of Thessaly\n* \'Aspetos\', "inimitable" or "vast",', 'inimitable|vast', 'NOUN', 'Achilles', 118)
# ('*', 'appos', 'Aemonia', 'a country which afterwards acquired the name of Thessaly\n* \'Aspetos\', "inimitable" or "vast",', 'inimitable|vast', 'NOUN', 'Achilles', 119)
# ('inimitable', 'appos', 'Aemonia', 'a country which afterwards acquired the name of Thessaly\n* \'Aspetos\', "inimitable" or "vast",', 'inimitable|vast', 'ADJ', 'Achilles', 120)
# ('vast', 'appos', 'Aemonia', 'a country which afterwards acquired the name of Thessaly\n* \'Aspetos\', "inimitable" or "vast",', 'inimitable|vast', 'ADJ', 'Achilles', 121)
# ('name', 'appos', 'Thessaly\n* \'Aspetos\', "inimitable" or "vast', 'his name at Epirus\n', None, 'NOUN', 'Achilles', 122)
# ('account', 'of', 'of Statius he raped', None, None, 'NOUN', 'Achilles', 123)
# ('live', 'v2np', 'There, Achilles, properly disguised, lived among Lycomedes\' daughters, perhaps under the name "Pyrrha" (the red-haired girl), Cercysera or Aissa ("swift").', 'Achilles, properly disguised,', 'there', 'VERB', 'Achilles', 124)
# ('call', 'v2np', "Lycomedes' daughter Deidamia, whom in the account of Statius he raped, Achilles there fathered two sons, Neoptolemus (also called Pyrrhus, after his father's possible alias) and Oneiros.", "Lycomedes' daughter Deidamia, whom in the account of Statius he raped, Achilles there fathered two sons, Neoptolemus", 'also|Pyrrhus|Oneiros', 'VERB', 'Achilles', 125)
# ('father', 'v2np', 'whom in the account of Statius he raped, Achilles there fathered two sons, Neoptolemus', 'Achilles there', 'son', 'VERB', 'Achilles', 126)
# ('learn', 'v2np', "According to this story, Odysseus learned from the prophet Calchas that the Achaeans would be unable to capture Troy without Achilles' aid.", 'Odysseus', None, 'VERB', 'Achilles', 127)
# ('go', 'v2np', "Odysseus went to Skyros in the guise of a peddler selling women's clothes and jewellery and placed a shield and spear among his goods.", 'Odysseus', 'place', 'VERB', 'Achilles', 128)
# ('take', 'v2np', 'When Achilles instantly took up the spear', 'Achilles', 'when|instantly|up|spear', 'VERB', 'Achilles', 129)
# ('see', 'v2np', 'When Achilles instantly took up the spear, Odysseus saw through his disguise and convinced him to join the Greek campaign.', 'Odysseus', 'convince', 'VERB', 'Achilles', 130)
# ('arrange', 'v2np', "In another version of the story, Odysseus arranged for a trumpet alarm to be sounded while he was with Lycomedes' women.", 'Odysseus', None, 'VERB', 'Achilles', 131)
# ('prepare', 'v2np', 'the women fled in panic, Achilles prepared to defend the court, thus giving his identity away.', 'Achilles', None, 'VERB', 'Achilles', 132)
# ('unable', 'acomp', 'the Achaeans', 'unable', None, 'ADJ', 'Achilles', 133)
# ('trilogy', 'of', 'of plays about Achilles', None, None, 'NOUN', 'Achilles', 134)
# ('deeds', 'of', 'of Achilles', None, None, 'NOUN', 'Achilles', 135)
# ('defeat', 'of', 'of Hector and eventual death', None, None, 'NOUN', 'Achilles', 136)
# ('fragments', 'of', 'of the Achilleis', None, 'extant|fragments', 'NOUN', 'Achilles', 137)
# ('part', 'of', 'of the Achilleis trilogy', None, 'first', 'NOUN', 'Achilles', 138)
# ('write', 'v2np', ' \nThe Greek tragedian Aeschylus wrote a trilogy of plays about Achilles, given the title Achilleis by modern scholars.', ' \nThe Greek tragedian Aeschylus', 'trilogy', 'VERB', 'Achilles', 139)
# ('puncture', 'v2np', 'when an arrow shot by Paris and guided by Apollo punctures his heel', 'an arrow shot by Paris and guided by Apollo', 'when|heel', 'VERB', 'Achilles', 140)
# ('focus', 'v2np', 'The first part of the Achilleis trilogy, The Myrmidons, focused on the relationship between Achilles and chorus, who represent the Achaean army and try to convince Achilles to give up his quarrel with Agamemnon', 'The first part of the Achilleis trilogy, The Myrmidons,', None, 'VERB', 'Achilles', 141)
# ('point', 'v2np', "In Plato's Symposium, Phaedrus points out that Aeschylus portrayed Achilles as the lover and Patroclus as the beloved", 'Phaedrus', 'out', 'VERB', 'Achilles', 142)
# ('portray', 'v2np', 'Aeschylus portrayed Achilles as the lover and Patroclus as the beloved', 'Aeschylus', 'Achilles', 'VERB', 'Achilles', 143)
# ('argue', 'v2np', "In Plato's Symposium, Phaedrus points out that Aeschylus portrayed Achilles as the lover and Patroclus as the beloved; Phaedrus argues that this is incorrect because Achilles, being the younger and more beautiful of the two, was the beloved, who loved his lover so much that he chose to die to avenge him.", 'Phaedrus', 'be', 'VERB', 'Achilles', 144)
# ('extant', 'adj2np', 'Extant fragments of the Achilleis and other Aeschylean fragments', None, None, 'ADJ', 'Achilles', 145)
# ('first', 'adj2np', 'The first part of the Achilleis trilogy', None, None, 'ADJ', 'Achilles', 146)
# ('young', 'acomp', 'Achilles', 'the younger', None, 'ADJ', 'Achilles', 147)
# ('zeno', 'of', 'of Elea', None, None, 'PROPN', 'Achilles', 148)
# ('student', 'of', 'of the monist Parmenides and a member of the Eleatic school', None, None, 'NOUN', 'Achilles', 149)
# ('centre', 'v2np', '  The philosopher Zeno of Elea centred one of his paradoxes on an imaginary footrace between "swift-footed" Achilles and a tortoise, by which he attempted to show that Achilles could not catch up to a tortoise with a head start, and therefore that motion and change were impossible.', '  The philosopher Zeno of Elea', 'one', 'VERB', 'Achilles', 150)
# ('catch', 'v2np', 'Achilles could not catch up to a tortoise with a head start', 'Achilles', 'up', 'VERB', 'Achilles', 151)
# ('believe', 'v2np', 'As a student of the monist Parmenides and a member of the Eleatic school, Zeno believed time and motion to be illusions.', 'Zeno', 'time', 'VERB', 'Achilles', 152)
# ('imaginary', 'adj2np', 'an imaginary footrace between "swift-footed" Achilles and a tortoise, by which he attempted to show that Achilles could not catch up to a tortoise with a head start, and therefore that motion and change were impossible', None, None, 'ADJ', 'Achilles', 153)
# ('use', 'v2np', 'Socrates uses various analogies, discussing athletics and the sciences to prove his point.', 'Socrates', 'analogy', 'VERB', 'Achilles', 154)
# ('agree', 'v2np', 'Socrates and Hippias agree that Odysseus, who concocted a number of lies throughout the Odyssey and other stories in the Trojan War Cycle, was false intentionally.', 'Socrates and Hippias', None, 'VERB', 'Achilles', 155)
# ('tell', 'v2np', 'Achilles, like Odysseus, told numerous falsehoods.', 'Achilles', 'falsehood', 'VERB', 'Achilles', 156)
# ('believe', 'v2np', 'Hippias believes that Achilles was a generally honest man, while Socrates believes that Achilles lied for his own benefit.', 'Hippias', None, 'VERB', 'Achilles', 157)
# ('believe', 'v2np', 'Socrates believes that Achilles lied for his own benefit', 'Socrates', None, 'VERB', 'Achilles', 158)
# ('lie', 'v2np', 'Achilles lied for his own benefit', 'Achilles', None, 'VERB', 'Achilles', 159)
# ('abandon', 'v2np', 'Socrates eventually abandons Homeric arguments and makes sports analogies to drive home the point: someone who does wrong on purpose is a better person than someone who does wrong unintentionally.', 'Socrates', 'eventually|argument|make', 'VERB', 'Achilles', 160)
# ('arrogant', 'adj2np', 'an arrogant man named Hippias', None, None, 'ADJ', 'Achilles', 161)
# ('other', 'adj2np', 'other stories in the Trojan War Cycle', None, None, 'ADJ', 'Achilles', 162)
# ('false', 'acomp', 'Odysseus, who concocted a number of lies throughout the Odyssey and other stories in the Trojan War Cycle', 'false', None, 'ADJ', 'Achilles', 163)
# ('honest', 'attr', 'Achilles', 'a generally honest man', None, 'ADJ', 'Achilles', 164)
# ('man', 'attr', 'Achilles', 'a generally honest man', 'honest', 'NOUN', 'Achilles', 165)
# ('dialogue', 'appos', 'Hippias Minor', 'a dialogue attributed to Plato,', None, 'NOUN', 'Achilles', 166)
# ('arrogant', 'appos', 'Plato', 'an arrogant man named Hippias', 'arrogant', 'ADJ', 'Achilles', 167)
# ('man', 'appos', 'Plato', 'an arrogant man named Hippias', 'arrogant', 'NOUN', 'Achilles', 168)
# ('view', 'of', 'of Achilles', None, 'negative', 'NOUN', 'Achilles', 169)
# ('accounts', 'of', 'of the Trojan War', None, 'latin', 'NOUN', 'Achilles', 170)
# ('versions', 'of', 'of the Matter of Troy', None, 'read', 'NOUN', 'Achilles', 171)
# ('matter', 'of', 'of Troy', None, None, 'PROPN', 'Achilles', 172)
# ('take', 'v2np', ' The Romans, who traditionally traced their lineage to Troy, took a highly negative view of Achilles.', ' The Romans, who traditionally traced their lineage to Troy,', 'view', 'VERB', 'Achilles', 173)
# ('refer', 'v2np', 'Virgil refers to Achilles as a savage and a merciless butcher of men, while Horace portrays Achilles ruthlessly slaying women and children.', 'Virgil', None, 'VERB', 'Achilles', 174)
# ('portray', 'v2np', 'Horace portrays Achilles ruthlessly slaying women and children', 'Horace', 'Achilles', 'VERB', 'Achilles', 175)
# ('represent', 'v2np', "Other writers, such as Catullus, Propertius, and Ovid, represent a second strand of disparagement, with an emphasis on Achilles' erotic career.", 'Other writers, such as Catullus, Propertius, and Ovid,', 'strand', 'VERB', 'Achilles', 176)
# ('negative', 'adj2np', 'a highly negative view of Achilles', None, None, 'ADJ', 'Achilles', 177)
# ('other', 'adj2np', 'Other writers, such as Catullus, Propertius, and Ovid', None, None, 'ADJ', 'Achilles', 178)
# ('erotic', 'adj2np', "Achilles' erotic career", None, None, 'ADJ', 'Achilles', 179)
# ('latin', 'adj2np', 'Latin accounts of the Trojan War', None, None, 'ADJ', 'Achilles', 180)
# ('read', 'adj2np', 'the most widely read and retold versions of the Matter of Troy', None, None, 'ADJ', 'Achilles', 181)
# ('leader', 'of', 'of the new Republican Party', None, None, 'NOUN', 'Abraham Lincoln', 182)
# ('states', 'of', 'of America', None, 'formed', 'PROPN', 'Abraham Lincoln', 183)
# ('run', 'v2np', 'Lincoln ran for president in 1860, sweeping the North to gain victory.', 'Lincoln', None, 'VERB', 'Abraham Lincoln', 184)
# ('view', 'v2np', 'Pro-slavery elements in the South viewed his election as a threat to slavery, and Southern states began seceding from the Union.', 'Pro-slavery elements in the South', 'election|begin', 'VERB', 'Abraham Lincoln', 185)
# ('begin', 'v2np', 'During this time, the newly formed Confederate States of America began seizing federal military bases in the south.', 'the newly formed Confederate States of America', None, 'VERB', 'Abraham Lincoln', 186)
# ('assume', 'v2np', 'Just over one month after Lincoln assumed the presidency', 'Lincoln', 'presidency', 'VERB', 'Abraham Lincoln', 187)
# ('attack', 'v2np', 'Just over one month after Lincoln assumed the presidency, the Confederate States attacked Fort Sumter, a U.S. fort in South Carolina.', 'the Confederate States', 'Sumter', 'VERB', 'Abraham Lincoln', 188)
# ('mobilize', 'v2np', 'Following the bombardment, Lincoln mobilized forces to suppress the rebellion and restore the Union.', 'Lincoln', 'force', 'VERB', 'Abraham Lincoln', 189)
# ('successful', 'adj2np', 'his successful law practice in central Illinois', None, None, 'ADJ', 'Abraham Lincoln', 190)
# ('pro', 'adj2np', 'Pro-slavery elements in the South', None, None, 'ADJ', 'Abraham Lincoln', 191)
# ('-', 'adj2np', 'Pro-slavery elements in the South', None, None, 'ADJ', 'Abraham Lincoln', 192)
# ('slavery', 'adj2np', 'Pro-slavery elements in the South', None, None, 'ADJ', 'Abraham Lincoln', 193)
# ('fort', 'appos', 'Fort Sumter', 'a U.S. fort in South Carolina', None, 'NOUN', 'Abraham Lincoln', 194)
# ('treatment', 'of', 'of the Southern Confederates', None, 'harsh', 'NOUN', 'Abraham Lincoln', 195)
# ('blockade', 'of', "of the South's trade", None, 'naval', 'NOUN', 'Abraham Lincoln', 196)
# ('service', 'of', 'of the United States', None, 'armed', 'NOUN', 'Abraham Lincoln', 197)
# ('have', 'v2np', 'Lincoln, a moderate Republican, had to navigate a contentious array of factions with friends and opponents from both the Democratic and Republican parties.', 'Lincoln, a moderate Republican', None, 'VERB', 'Abraham Lincoln', 198)
# ('demand', 'v2np', 'His allies, the War Democrats and the Radical Republicans, demanded harsh treatment of the Southern Confederates.', 'His allies, the War Democrats and the Radical Republicans,', 'treatment', 'VERB', 'Abraham Lincoln', 199)
# ('call', 'v2np', 'Anti-war Democrats (called "Copperheads") despised Lincoln, and irreconcilable pro-Confederate elements plotted his assassination.', 'Anti-war Democrats', None, 'VERB', 'Abraham Lincoln', 200)
# ('come', 'v2np', 'His Gettysburg Address came to be seen as one of the greatest and most influential statements of American national purpose.', 'His Gettysburg Address', None, 'VERB', 'Abraham Lincoln', 201)
# ('supervise', 'v2np', "Lincoln closely supervised the strategy and tactics in the war effort, including the selection of generals, and implemented a naval blockade of the South's trade.", 'Lincoln', 'closely|strategy|implement', 'VERB', 'Abraham Lincoln', 202)
# ('pressure', 'v2np', 'Lincoln also pressured border states to outlaw slavery, and he promoted the Thirteenth Amendment to the United States Constitution, which upon its ratification abolished slavery.', 'Lincoln', 'also|state|promote', 'VERB', 'Abraham Lincoln', 203)
# ('harsh', 'adj2np', 'harsh treatment of the Southern Confederates', None, None, 'ADJ', 'Abraham Lincoln', 204)
# ('naval', 'adj2np', "a naval blockade of the South's trade", None, None, 'ADJ', 'Abraham Lincoln', 205)
# ('armed', 'adj2np', 'the armed service of the United States', None, None, 'ADJ', 'Abraham Lincoln', 206)
# ('moderate', 'appos', 'Lincoln', 'a moderate Republican', 'moderate', 'ADJ', 'Abraham Lincoln', 207)
# ('manage', 'v2np', 'Lincoln managed his own successful re-election campaign.', 'Lincoln', 'campaign', 'VERB', 'Abraham Lincoln', 208)
# ('national', 'adj2np', 'a national hero for his wartime leadership and for his efforts to preserve the Union and abolish slavery', None, None, 'ADJ', 'Abraham Lincoln', 209)
# ('child', 'of', 'of Thomas Lincoln and Nancy Hanks Lincoln', None, 'second', 'NOUN', 'Abraham Lincoln', 210)
# ('descendant', 'of', 'of Samuel Lincoln, an Englishman who migrated from Hingham, Norfolk, to its namesake, Hingham, Massachusetts, in 1638', None, None, 'NOUN', 'Abraham Lincoln', 211)
# ('descendant', 'of', 'of the Harrison family of Virginia', None, None, 'NOUN', 'Abraham Lincoln', 212)
# ('family', 'of', 'of Virginia', None, None, 'NOUN', 'Abraham Lincoln', 213)
# ('move', 'v2np', 'his paternal grandfather and namesake, Captain Abraham Lincoln and wife Bathsheba (née Herring) moved the family from Virginia to Jefferson County, Kentucky.', 'his paternal grandfather and namesake, Captain Abraham Lincoln and wife Bathsheba (née Herring)', 'family', 'VERB', 'Abraham Lincoln', 214)
# ('witness', 'v2np', "His children, including eight-year-old Thomas, Abraham's father, witnessed the attack.", "His children, including eight-year-old Thomas, Abraham's father,", 'attack', 'VERB', 'Abraham Lincoln', 215)
# ('work', 'v2np', 'Thomas then worked at odd jobs in Kentucky and Tennessee before the family settled in Hardin County, Kentucky, in the early 1800s.', 'Thomas', 'then', 'VERB', 'Abraham Lincoln', 216)
# ('second', 'adj2np', 'the second child of Thomas Lincoln and Nancy Hanks Lincoln', None, None, 'ADJ', 'Abraham Lincoln', 217)
# ('odd', 'adj2np', 'odd jobs in Kentucky and Tennessee', None, None, 'ADJ', 'Abraham Lincoln', 218)
# ('descendant', 'attr', 'Lincoln', 'a descendant', None, 'NOUN', 'Abraham Lincoln', 219)
# ('second', 'appos', 'February 12, 1809', 'the second child of Thomas Lincoln and Nancy Hanks Lincoln', 'second', 'ADJ', 'Abraham Lincoln', 220)
# ('child', 'appos', 'February 12, 1809', 'the second child of Thomas Lincoln and Nancy Hanks Lincoln', 'second', 'NOUN', 'Abraham Lincoln', 221)
# ('father', 'appos', 'eight-year-old Thomas', "Abraham's father", None, 'NOUN', 'Abraham Lincoln', 222)
# ('members', 'of', 'of a Separate Baptists church, which forbade alcohol, dancing, and slavery', None, None, 'NOUN', 'Abraham Lincoln', 223)
# ('buy', 'v2np', 'Thomas Lincoln bought or leased farms in Kentucky before losing all but  of his land in court disputes over property titles.', 'Thomas Lincoln', 'lease', 'VERB', 'Abraham Lincoln', 224)
# ('note', 'v2np', 'In 1860, Lincoln noted that the family\'s move to Indiana was "partly on account of slavery", but mainly due to land title difficulties.\n', 'Lincoln', None, 'VERB', 'Abraham Lincoln', 225)
# ('work', 'v2np', 'The farm site where Lincoln grew up in Spencer County, Indiana\nIn Kentucky and Indiana, Thomas worked as a farmer, cabinetmaker, and carpenter.', 'The farm site where Lincoln grew up in Spencer County, Indiana\nIn Kentucky and Indiana', None, 'VERB', 'Abraham Lincoln', 226)
# ('grow', 'v2np', 'where Lincoln grew up in Spencer County, Indiana\nIn Kentucky and Indiana', 'Lincoln', 'where|up', 'VERB', 'Abraham Lincoln', 227)
# ('work', 'v2np', 'The farm site where Lincoln grew up in Spencer County, Indiana\nIn Kentucky and Indiana, Thomas worked as a farmer, cabinetmaker, and carpenter.', 'Thomas', None, 'VERB', 'Abraham Lincoln', 228)
# ('unbroken', 'adj2np', 'an "unbroken forest" in Hurricane Township, Perry County', None, None, 'ADJ', 'Abraham Lincoln', 229)
# ('free', 'attr', 'Indiana', 'a "free" (non-slaveholding) territory', None, 'ADJ', 'Abraham Lincoln', 230)
# ('non', 'attr', 'Indiana', 'a "free" (non-slaveholding) territory', None, 'ADJ', 'Abraham Lincoln', 231)
# ('-', 'attr', 'Indiana', 'a "free" (non-slaveholding) territory', None, 'ADJ', 'Abraham Lincoln', 232)
# ('slaveholding', 'attr', 'Indiana', 'a "free" (non-slaveholding) territory', None, 'ADJ', 'Abraham Lincoln', 233)
# ('territory', 'attr', 'Indiana', 'a "free" (non-slaveholding) territory', 'free|non|-|slaveholding', 'NOUN', 'Abraham Lincoln', 234)
# ('member', 'attr', 'Thomas and Nancy', 'members', None, 'NOUN', 'Abraham Lincoln', 235)
# ('marry', 'v2np', 'On December 2, 1819, Thomas married Sarah Bush Johnston, a widow from Elizabethtown, Kentucky, with three children of her own.', 'Thomas', None, 'VERB', 'Abraham Lincoln', 236)
# ('marry', 'v2np', 'On December 2, 1819, Thomas married Sarah Bush Johnston, a widow from Elizabethtown, Kentucky, with three children of her own.', 'Sarah Bush Johnston, a widow from Elizabethtown, Kentucky, with three children of her own', None, 'VERB', 'Abraham Lincoln', 237)
# ('become', 'v2np', 'Abraham became close to his stepmother and called her "Mother".', 'Abraham', 'call', 'VERB', 'Abraham Lincoln', 238)
# ('dislike', 'v2np', 'Lincoln disliked the hard labor associated with farm life.', 'Lincoln', 'labor', 'VERB', 'Abraham Lincoln', 239)
# ('autobiography', 'of', 'of Benjamin Franklin', None, None, 'NOUN', 'Abraham Lincoln', 240)
# ('leader', 'of', 'of ruffians known as "the Clary\'s Grove Boys', None, 'renowned', 'NOUN', 'Abraham Lincoln', 241)
# ('take', 'v2np', 'As a teen, Lincoln took responsibility for chores and customarily gave his father all earnings from work outside the home until he was 21.', 'Lincoln', 'responsibility|give', 'VERB', 'Abraham Lincoln', 242)
# ('short', 'adj2np', 'two short stints in Kentucky, where he learned to read but probably not to write, at age seven, and', None, None, 'ADJ', 'Abraham Lincoln', 243)
# ('renowned', 'adj2np', 'the renowned leader of ruffians known as "the Clary\'s Grove Boys', None, None, 'ADJ', 'Abraham Lincoln', 244)
# ('tall', 'acomp', 'Lincoln', 'tall', None, 'ADJ', 'Abraham Lincoln', 245)
# ('members', 'of', 'of the extended Lincoln family, including Abraham', None, 'several', 'NOUN', 'Abraham Lincoln', 246)
# ('move', 'v2np', 'In March 1830, fearing another milk sickness outbreak, several members of the extended Lincoln family, including Abraham, moved west to Illinois, a free state, and settled in Macon County.', 'several members of the extended Lincoln family, including Abraham,', 'west|settle', 'VERB', 'Abraham Lincoln', 247)
# ('become', 'v2np', "Abraham then became increasingly distant from Thomas, in part due to his father's lack of education.", 'Abraham', 'then', 'VERB', 'Abraham Lincoln', 248)
# ('prepare', 'v2np', 'Thomas and other family prepared to move to a new homestead in Coles County, Illinois', 'Thomas and other family', None, 'VERB', 'Abraham Lincoln', 249)
# ('strike', 'v2np', 'In 1831, as Thomas and other family prepared to move to a new homestead in Coles County, Illinois, Abraham struck out on his own.', 'Abraham', 'out', 'VERB', 'Abraham Lincoln', 250)
# ('take', 'v2np', 'Lincoln and some friends took goods by flatboat to New Orleans, Louisiana, where he was first exposed to slavery.', 'Lincoln and some friends', 'good', 'VERB', 'Abraham Lincoln', 251)
# ('several', 'adj2np', 'several members of the extended Lincoln family, including Abraham', None, None, 'ADJ', 'Abraham Lincoln', 252)
# ('extended', 'adj2np', 'the extended Lincoln family, including Abraham', None, None, 'ADJ', 'Abraham Lincoln', 253)
# ('new', 'adj2np', 'a new homestead in Coles County', None, None, 'ADJ', 'Abraham Lincoln', 254)
# ('free', 'appos', 'Illinois', 'a free state', 'free', 'ADJ', 'Abraham Lincoln', 255)
# ('state', 'appos', 'Illinois', 'a free state', 'free', 'NOUN', 'Abraham Lincoln', 256)
# ('daughter', 'of', 'of Robert Smith Todd, a wealthy lawyer and businessman in Lexington, Kentucky', None, None, 'NOUN', 'Abraham Lincoln', 257)
# ('mansion', 'of', "of Mary's sister", None, None, 'NOUN', 'Abraham Lincoln', 258)
# ('meet', 'v2np', 'In 1839, Lincoln met Mary Todd in Springfield, Illinois, and the following year they became engaged.', 'Lincoln', 'Todd|become', 'VERB', 'Abraham Lincoln', 259)
# ('keep', 'v2np', 'Mary kept house with the help of a hired servant and a relative.', 'Mary', 'house', 'VERB', 'Abraham Lincoln', 260)
# ('wealthy', 'adj2np', 'a wealthy lawyer and businessman in Lexington', None, None, 'ADJ', 'Abraham Lincoln', 261)
# ('wealthy', 'appos', 'Robert Smith Todd', 'a wealthy lawyer and businessman in Lexington,', 'wealthy', 'ADJ', 'Abraham Lincoln', 262)
# ('lawyer', 'appos', 'Robert Smith Todd', 'a wealthy lawyer and businessman in Lexington,', 'wealthy', 'NOUN', 'Abraham Lincoln', 263)
# ('businessman', 'appos', 'Robert Smith Todd', 'a wealthy lawyer and businessman in Lexington,', 'wealthy', 'NOUN', 'Abraham Lincoln', 264)
# ('died', 'of', 'of a fever at the White House', None, None, 'VERB', 'Abraham Lincoln', 265)
# ('out', 'of', 'of respect for Lincoln', None, 'yet', 'ADP', 'Abraham Lincoln', 266)
# ('die', 'v2np', 'Edward Baker Lincoln (Eddie), born in 1846, died February 1, 1850, probably of tuberculosis.', 'Edward Baker Lincoln (Eddie), born in 1846,', None, 'VERB', 'Abraham Lincoln', 267)
# ('grow', 'v2np', "In fact, Lincoln's law partner William H. Herndon would grow irritated when Lincoln brought his children to the law office.", "Lincoln's law partner William H. Herndon", None, 'VERB', 'Abraham Lincoln', 268)
# ('bring', 'v2np', 'when Lincoln brought his children to the law office', 'Lincoln', 'when|child', 'VERB', 'Abraham Lincoln', 269)
# ('recount', 'v2np', 'Herndon recounted, "I have felt many and many a time that I wanted to wring their little necks, and yet out of respect for Lincoln I kept my mouth shut.', 'Herndon', None, 'VERB', 'Abraham Lincoln', 270)
# ('note', 'v2np', 'Lincoln did not note what his children were doing or had done."', 'Lincoln', None, 'VERB', 'Abraham Lincoln', 271)
# ('third', 'adj2np', "Lincoln's third son", None, None, 'ADJ', 'Abraham Lincoln', 272)
# ('affectionate', 'attr', 'Lincoln', 'an affectionate husband', None, 'ADJ', 'Abraham Lincoln', 273)
# ('husband', 'attr', 'Lincoln', 'an affectionate husband', 'affectionate', 'NOUN', 'Abraham Lincoln', 274)
# ('fond', 'acomp', 'Lincoln', 'fond', None, 'ADJ', 'Abraham Lincoln', 275)
# ('house', 'of', 'of Representatives', None, None, 'PROPN', 'Abraham Lincoln', 276)
# ('work', 'v2np', 'During 1831 and 1832, Lincoln worked at a general store in New Salem, Illinois.', 'Lincoln', None, 'VERB', 'Abraham Lincoln', 277)
# ('return', 'v2np', 'When Lincoln returned home from the Black Hawk War', 'Lincoln', 'when|home', 'VERB', 'Abraham Lincoln', 278)
# ('obtain', 'v2np', 'a license was required to sell customers single beverages, Berry obtained bartending licenses for $7 each for Lincoln and himself, and in 1833 the Lincoln-Berry General Store became a tavern as well.', 'Berry', 'become', 'VERB', 'Abraham Lincoln', 279)
# ('become', 'v2np', 'in 1833 the Lincoln-Berry General Store became a tavern as well.', 'the Lincoln-Berry General Store', 'well', 'VERB', 'Abraham Lincoln', 280)
# ('become', 'v2np', 'But Berry became an alcoholic, was often too drunk to work, and Lincoln ended up running the store by himself.', 'Berry', 'be|end', 'VERB', 'Abraham Lincoln', 281)
# ('end', 'v2np', 'Lincoln ended up running the store by himself.', 'Lincoln', 'up', 'VERB', 'Abraham Lincoln', 282)
# ('sell', 'v2np', 'Lincoln to sell his share', 'Lincoln', 'share', 'VERB', 'Abraham Lincoln', 283)
# ('general', 'adj2np', 'a general store in New Salem', None, None, 'ADJ', 'Abraham Lincoln', 284)
# ('general', 'adj2np', 'a New Salem general store on credit', None, None, 'ADJ', 'Abraham Lincoln', 285)
# ('able', 'acomp', 'Lincoln and Berry', 'able', None, 'ADJ', 'Abraham Lincoln', 286)
# ('277', 'of', 'of the 300 votes cast in the New Salem precinct', None, None, 'NUM', 'Abraham Lincoln', 287)
# ('observe', 'v2np', 'In his first campaign speech after returning from his military service, Lincoln observed a supporter in the crowd under attack, grabbed the assailant by his "neck and the seat of his trousers", and tossed him.', 'Lincoln', 'supporter|grab', 'VERB', 'Abraham Lincoln', 288)
# ('advocate', 'v2np', 'In the campaign, Lincoln advocated for navigational improvements on the Sangamon River.', 'Lincoln', None, 'VERB', 'Abraham Lincoln', 289)
# ('finish', 'v2np', 'Lincoln finished eighth out of 13 candidates (the top four were elected), though he received 277 of the 300 votes cast in the New Salem precinct.', 'Lincoln', 'eighth', 'VERB', 'Abraham Lincoln', 290)
# ('navigational', 'adj2np', 'navigational improvements on the Sangamon River', None, None, 'ADJ', 'Abraham Lincoln', 291)
# ('serve', 'v2np', "Lincoln served as New Salem's postmaster and later as county surveyor, but continued his voracious reading and decided to become a lawyer.", 'Lincoln', 'later|continue', 'VERB', 'Abraham Lincoln', 292)
# ('borrow', 'v2np', "Rather than studying in the office of an established attorney, as was the custom, Lincoln borrowed legal texts from attorneys John Todd Stuart and Thomas Drummond, purchased books including Blackstone's Commentaries and Chitty's Pleadings, and read law on his own.", 'Lincoln', 'text|purchase', 'VERB', 'Abraham Lincoln', 293)
# ('house', 'of', 'of Representatives', None, None, 'PROPN', 'Abraham Lincoln', 294)
# ('construction', 'of', 'of the Illinois and Michigan Canal', None, None, 'NOUN', 'Abraham Lincoln', 295)
# ('program', 'of', 'of abolition in conjunction with settling freed slaves in Liberia', None, None, 'NOUN', 'Abraham Lincoln', 296)
# ('second', 'adj2np', "Illinois\nLincoln's second state house campaign", None, None, 'ADJ', 'Abraham Lincoln', 297)
# ('freed', 'adj2np', 'freed slaves in Liberia', None, None, 'ADJ', 'Abraham Lincoln', 298)
# ('second', 'appos', 'Springfield', "Illinois\nLincoln's second state house campaign", 'second', 'ADJ', 'Abraham Lincoln', 299)
# ('state', 'appos', 'Springfield', "Illinois\nLincoln's second state house campaign", 'second', 'NOUN', 'Abraham Lincoln', 300)
# ('house', 'appos', 'Springfield', "Illinois\nLincoln's second state house campaign", 'second', 'NOUN', 'Abraham Lincoln', 301)
# ('campaign', 'appos', 'Springfield', "Illinois\nLincoln's second state house campaign", 'second', 'NOUN', 'Abraham Lincoln', 302)
# ('house', 'of', 'of Representatives', None, None, 'PROPN', 'Abraham Lincoln', 303)
# ('district', 'of', 'of Columbia', None, None, 'PROPN', 'Abraham Lincoln', 304)
# ('seek', 'v2np', "In 1843, Lincoln sought the Whig nomination for Illinois' 7th district seat in the U.S. House of Representatives", 'Lincoln', 'nomination', 'VERB', 'Abraham Lincoln', 305)
# ('pull', 'v2np', 'Lincoln not only pulled off his strategy of gaining the nomination in 1846 but also won the election.', 'Lincoln', 'off|strategy|win', 'VERB', 'Abraham Lincoln', 306)
# ('team', 'v2np', 'Lincoln teamed with Joshua R. Giddings on a bill to abolish slavery in the District of Columbia with compensation for the owners, enforcement to capture fugitive slaves, and a popular vote on the matter.', 'Lincoln', None, 'VERB', 'Abraham Lincoln', 307)
# ('whig', 'adj2np', "the Whig nomination for Illinois' 7th district seat in the U.S. House of Representatives", None, None, 'ADJ', 'Abraham Lincoln', 308)
# ('7th', 'adj2np', "Illinois' 7th district seat in the U.S. House of Representatives", None, None, 'ADJ', 'Abraham Lincoln', 309)
# ('emphasize', 'v2np', 'Lincoln emphasized his opposition to Polk by drafting and introducing his Spot Resolutions.', 'Lincoln', 'opposition', 'VERB', 'Abraham Lincoln', 310)
# ...
# ('centre', 'of', 'of Lesbos', None, None, 'NOUN', 'Aristotle', 895)
# ('history', 'of', 'of Animals, Generation of Animals, Movement of Animals', None, None, 'NOUN', 'Aristotle', 896)
# ('generation', 'of', 'of Animals, Movement of Animals', None, None, 'NOUN', 'Aristotle', 897)
# ('movement', 'of', 'of Animals', None, None, 'PROPN', 'Aristotle', 898)
# ('parts', 'of', 'of Animals', None, None, 'PROPN', 'Aristotle', 899)
# ('survive', 'v2np', 'two books on plants by his pupil Theophrastus have survived.', 'two books on plants by his pupil Theophrastus', None, 'VERB', 'Aristotle', 900)
# ('surrounding', 'adj2np', 'the surrounding seas, including in particular the Pyrrha lagoon in the centre of Lesbos', None, None, 'ADJ', 'Aristotle', 901)
# ('first', 'attr', ' Aristotle', 'the first person', None, 'ADJ', 'Aristotle', 902)
# ('person', 'attr', ' Aristotle', 'the first person', 'first', 'NOUN', 'Aristotle', 903)
# ('gives', 'of', 'of the ovoviviparous embryological development of the hound shark', None, 'of', 'VERB', 'Aristotle', 904)
# ('development', 'of', 'of the hound shark', None, 'ovoviviparous|embryological', 'NOUN', 'Aristotle', 905)
# ('report', 'v2np', 'Aristotle reports on the sea-life visible from observation on Lesbos and the catches of fishermen.', 'Aristotle', None, 'VERB', 'Aristotle', 906)
# ('visible', 'adj2np', 'the sea-life visible from observation on Lesbos and the catches of fishermen', None, None, 'ADJ', 'Aristotle', 907)
# ('ovoviviparous', 'adj2np', 'the ovoviviparous embryological development of the hound shark', None, None, 'ADJ', 'Aristotle', 908)
# ('embryological', 'adj2np', 'the ovoviviparous embryological development of the hound shark', None, None, 'ADJ', 'Aristotle', 909)
# ('critical', 'of', 'of Empedocles\'s materialist theory of a "survival of the fittest" origin of living things and their organs', None, 'thus', 'ADJ', 'Aristotle', 910)
# ('note', 'v2np', 'Darwin, too, noted these sorts of differences between similar kinds of animal, but unlike Aristotle used the data to come to the theory of evolution.', 'Darwin', 'too|sort|use', 'VERB', 'Aristotle', 911)
# ('use', 'v2np', 'Aristotle used the data to come to the theory of evolution', 'Aristotle', 'datum', 'VERB', 'Aristotle', 912)
# ('seem', 'v2np', "Aristotle's writings can seem to modern readers close to implying evolution, but while Aristotle was aware that new mutations or hybridizations could occur, he saw these as rare accidents.", "Aristotle's writings", 'see', 'VERB', 'Aristotle', 913)
# ('materialist', 'adj2np', 'Empedocles\'s materialist theory of a "survival of the fittest" origin of living things and their organs', None, None, 'ADJ', 'Aristotle', 914)
# ('aware', 'acomp', 'Aristotle', 'aware', None, 'ADJ', 'Aristotle', 915)
# ('accident', 'appos', 'Aristotle', 'accidents, like heat waves in winter', None, 'NOUN', 'Aristotle', 916)
# ('heat', 'appos', 'Aristotle', 'accidents, like heat waves in winter', None, 'NOUN', 'Aristotle', 917)
# ('wave', 'appos', 'Aristotle', 'accidents, like heat waves in winter', None, 'NOUN', 'Aristotle', 918)
# ('winter', 'appos', 'Aristotle', 'accidents, like heat waves in winter', None, 'NOUN', 'Aristotle', 919)
# ('scientific', 'acomp', "Aristotle's biology", 'scientific', None, 'ADJ', 'Aristotle', 920)
# ('infer', 'v2np', 'From the data he collected and documented, Aristotle inferred quite a number of rules relating the life-history features of the live-bearing tetrapods (terrestrial placental mammals) that he studied.', 'Aristotle', 'number', 'VERB', 'Aristotle', 921)
# ('history', 'of', 'of Animals', None, None, 'NOUN', 'Aristotle', 922)
# ('version', 'of', 'of the scala naturae', None, 'nonreligious', 'NOUN', 'Aristotle', 923)
# ('distinguish', 'v2np', 'Aristotle distinguished about 500 species of animals, arranging these in the History of Animals in a graded scale of perfection, a nonreligious version of the scala naturae, with man at the top.', 'Aristotle', 'specie|version', 'VERB', 'Aristotle', 924)
# ('nonreligious', 'adj2np', 'a nonreligious version of the scala naturae, with man at the top', None, None, 'ADJ', 'Aristotle', 925)
# ('posit', 'v2np', 'Aristotle\'s psychology, given in his treatise On the Soul (peri psychēs), posits three kinds of soul ("psyches"): the vegetative soul, the sensitive soul, and the rational soul.', "Aristotle's psychology, given in his treatise On the Soul (peri psychēs),", 'kind', 'VERB', 'Aristotle', 926)
# ('case', 'of', 'of plants, growth and chemical transformations, which Aristotle considers types of movement', None, None, 'NOUN', 'Aristotle', 927)
# ('exception', 'of', 'of Alcmaeon', None, None, 'NOUN', 'Aristotle', 928)
# ('consider', 'v2np', 'which Aristotle considers types of movement', 'Aristotle', 'which|type', 'VERB', 'Aristotle', 929)
# ('interpretation', 'of', 'of Plato', None, None, 'NOUN', 'Aristotle', 930)
# ('criticize', 'v2np', "In On the Soul, Aristotle famously criticizes Plato's theory of the soul and develops his own in response to Plato's.", 'Aristotle', 'famously|theory|develop', 'VERB', 'Aristotle', 931)
# ('entail', 'v2np', "Plato's view of reincarnation entails that it is possible for a soul and its body to be mis-matched", "Plato's view of reincarnation", None, 'VERB', 'Aristotle', 932)
# ('allege', 'v2np', ', Aristotle alleges,', 'Aristotle', None, 'VERB', 'Aristotle', 933)
# ('other', 'adj2np', "Aristotle's other criticism", None, None, 'ADJ', 'Aristotle', 934)
# ('believe', 'v2np', 'Aristotle believed an impression is left on a semi-fluid bodily organ that undergoes several changes in order to make a memory.', 'Aristotle', None, 'VERB', 'Aristotle', 935)
# ('use', 'v2np', "Aristotle uses the term 'memory' for the actual retaining of an experience in the impression that can develop from sensation, and for the intellectual anxiety that comes with the impression because it is formed at a particular time and processing specific contents.", 'Aristotle', 'memory', 'VERB', 'Aristotle', 936)
# ('believe', 'v2np', 'Aristotle believes people receive all kinds of sense perceptions and perceive them as impressions', 'Aristotle', None, 'VERB', 'Aristotle', 937)
# ('occur', 'v2np', 'Recollection occurs when one retrieved experience naturally follows another.', 'Recollection', None, 'VERB', 'Aristotle', 938)
# ('believe', 'v2np', 'Aristotle believed the chain of thought, which ends in recollection of certain impressions, was connected systematically in relationships such as similarity, contrast, and contiguity, described in his laws of association.', 'Aristotle', 'chain', 'VERB', 'Aristotle', 939)
# ('believe', 'v2np', 'Aristotle believed that past experiences are hidden within the mind.', 'Aristotle', None, 'VERB', 'Aristotle', 940)
# ('describe', 'v2np', 'Aristotle describes sleep in On Sleep and Wakefulness.', 'Aristotle', 'sleep', 'VERB', 'Aristotle', 941)
# ('absence', 'of', 'of perception to the faculty of imagination, phantasia', None, None, 'NOUN', 'Aristotle', 942)
# ('explain', 'v2np', 'Aristotle explains that when a person stares at a moving stimulus such as the waves in a body of water, and then looks away, the next thing they look at appears to have a wavelike motion.', 'Aristotle', None, 'VERB', 'Aristotle', 943)
# ('compare', 'v2np', 'Aristotle compares a sleeping person to a person who is overtaken by strong feelings toward a stimulus.', 'Aristotle', 'person', 'VERB', 'Aristotle', 944)
# ('ascribe', 'v2np', 'In De Anima iii 3, Aristotle ascribes the ability to create, to store, and to recall images in the absence of perception to the faculty of imagination, phantasia.', 'Aristotle', 'ability|recall', 'VERB', 'Aristotle', 945)
# ('component', 'of', "of Aristotle's theory of dreams", None, None, 'NOUN', 'Aristotle', 946)
# ('disagree', 'v2np', "One component of Aristotle's theory of dreams disagrees with previously held beliefs.", "One component of Aristotle's theory of dreams", None, 'VERB', 'Aristotle', 947)
# ('reason', 'v2np', 'Aristotle reasoned naturalistically that instances in which dreams do resemble future events are simply coincidences.', 'Aristotle', 'naturalistically', 'VERB', 'Aristotle', 948)
# ('claim', 'v2np', 'Aristotle claimed that a dream is first established by the fact that the person is asleep when they experience it.', 'Aristotle', None, 'VERB', 'Aristotle', 949)
# ('teach', 'v2np', 'Aristotle taught that virtue has to do with the proper function (ergon) of a thing.', 'Aristotle', None, 'VERB', 'Aristotle', 950)
# ('reason', 'v2np', 'Aristotle reasoned that humans must have a function specific to humans, and that this function must be an activity of the psuchē (soul) in accordance with reason (logos).', 'Aristotle', None, 'VERB', 'Aristotle', 951)
# ('identify', 'v2np', 'Aristotle identified such an optimum activity (the virtuous mean, between the accompanying vices of excess or deficiency) of the soul as the aim of all human deliberate action, eudaimonia, generally translated as "happiness" or sometimes "well-being".', 'Aristotle', 'activity', 'VERB', 'Aristotle', 952)
# ('teach', 'v2np', 'Aristotle taught that to achieve a virtuous and potentially happy character requires a first stage of having the fortune to be habituated not deliberately, but by teachers, and experience, leading to a later stage in which one consciously chooses to do the best things.', 'Aristotle', 'that', 'VERB', 'Aristotle', 953)
# ('address', 'v2np', 'In addition to his works on ethics, which address the individual, Aristotle addressed the city in his work titled Politics.', 'Aristotle', 'city', 'VERB', 'Aristotle', 954)
# ('consider', 'v2np', 'Aristotle considered the city to be a natural community.', 'Aristotle', None, 'VERB', 'Aristotle', 955)
# ('exist', 'v2np', 'Aristotle conceived of politics as being like an organism rather than like a machine, and as a collection of parts none of which can exist without the others.', 'Aristotle conceived of politics as being like an organism rather than like a machine, and as a collection of parts', None, 'VERB', 'Aristotle', 956)
# ('organic', 'acomp', "Aristotle's conception of the city", 'organic', None, 'ADJ', 'Aristotle', 957)
# ('natural', 'adj2np', 'the natural community according to Aristotle', None, None, 'ADJ', 'Aristotle', 958)
# ('make', 'v2np', 'Aristotle made substantial contributions to economic thought, especially to thought in the Middle Ages.', 'Aristotle', 'contribution', 'VERB', 'Aristotle', 959)
# ('address', 'v2np', 'In Politics, Aristotle addresses the city, property, and trade.', 'Aristotle', 'city', 'VERB', 'Aristotle', 960)
# ('anticipate', 'v2np', "His response to criticisms of private property, in Lionel Robbins's view, anticipated later proponents of private property among philosophers and economists, as it related to the overall utility of social arrangements.", "His response to criticisms of private property, in Lionel Robbins's view", 'proponent', 'VERB', 'Aristotle', 961)
# ('believe', 'v2np', 'Aristotle believed that although communal arrangements may seem beneficial to society, and that although private property is often blamed for social strife, such evils in fact come from human nature.', 'Aristotle', None, 'VERB', 'Aristotle', 962)
# ('offer', 'v2np', 'In Politics, Aristotle offers one of the earliest accounts of the origin of money.', 'Aristotle', 'one', 'VERB', 'Aristotle', 963)
# ('consider', 'v2np', 'Similarly, Aristotle considered making a profit through interest unnatural, as it makes a gain out of the money itself, and not from its use.', 'Aristotle', 'similarly', 'VERB', 'Aristotle', 964)
# ('major', 'adj2np', 'a major influence on economic thought in the Middle Ages', None, None, 'ADJ', 'Aristotle', 965)
# ('economic', 'adj2np', 'economic thought in the Middle Ages', None, None, 'ADJ', 'Aristotle', 966)
# ('major', 'attr', "Aristotle's discussions on retail and interest", 'a major influence', None, 'ADJ', 'Aristotle', 967)
# ('influence', 'attr', "Aristotle's discussions on retail and interest", 'a major influence', 'major', 'NOUN', 'Aristotle', 968)
# ('give', 'v2np', 'Aristotle gave a summary of the function of money that was perhaps remarkably precocious for his time.', 'Aristotle', 'summary', 'VERB', 'Aristotle', 969)
# ('outline', 'v2np', 'Aristotle also outlines two kinds of rhetorical proofs: enthymeme (proof by syllogism) and paradeigma (proof by example).', 'Aristotle', 'also|kind', 'VERB', 'Aristotle', 970)
# ('epideictic', 'adj2np', 'epideictic (ceremonial speeches dealing with praise or blame), forensic (judicial speeches over guilt or innocence), and deliberative (speeches calling on an audience to make a decision on an issue)', None, None, 'ADJ', 'Aristotle', 971)
# ('ceremonial', 'adj2np', 'epideictic (ceremonial speeches dealing with praise or blame), forensic (judicial speeches over guilt or innocence), and deliberative (speeches calling on an audience to make a decision on an issue)', None, None, 'ADJ', 'Aristotle', 972)
# ('write', 'v2np', 'Aristotle writes in his Poetics that epic poetry, tragedy, comedy, dithyrambic poetry, painting, sculpture, music, and dance are all fundamentally acts of mimesis ("imitation"), each varying in imitation by medium, object, and manner.', 'Aristotle', None, 'VERB', 'Aristotle', 973)
# ('state', 'v2np', 'Aristotle states that mimesis is a natural instinct of humanity that separates humans from animals and that all human artistry "follows the pattern of nature".', 'Aristotle', None, 'VERB', 'Aristotle', 974)
# ('believe', 'v2np', 'Because of this, Aristotle believed that each of the mimetic arts possesses what Stephen Halliwell calls "highly structured procedures for the achievement of their purposes."', 'Aristotle', None, 'VERB', 'Aristotle', 975)
# ('call', 'v2np', 'what Stephen Halliwell calls "highly structured procedures for the achievement of their purposes', 'Stephen Halliwell', 'what', 'VERB', 'Aristotle', 976)
# ('riddles', 'of', 'of the Delphic Oracle', None, None, 'NOUN', 'Aristotle', 977)
# ('fables', 'of', 'of Aesop', None, None, 'NOUN', 'Aristotle', 978)
# ('comprise', 'v2np', "Aristotle's Poetics originally comprised two books – one on comedy and one on tragedy – only the portion that focuses on tragedy has survived", "Aristotle's Poetics", 'originally|book|survive', 'VERB', 'Aristotle', 979)
# ('teach', 'v2np', 'Aristotle taught that tragedy is composed of six elements: plot-structure, character, style, thought, spectacle, and lyric poetry.', 'Aristotle', None, 'VERB', 'Aristotle', 980)
# ('conclude', 'v2np', 'Aristotle concludes Poetics with a discussion on which, if either, is superior: epic or tragic mimesis.', 'Aristotle', 'Poetics', 'VERB', 'Aristotle', 981)
# ('special', 'adj2np', 'a special interest in the riddles of the Delphic Oracle', None, None, 'ADJ', 'Aristotle', 982)
# ('keen', 'attr', 'Aristotle', 'a keen systematic collector', None, 'ADJ', 'Aristotle', 983)
# ('systematic', 'attr', 'Aristotle', 'a keen systematic collector', None, 'ADJ', 'Aristotle', 984)
# ('collector', 'attr', 'Aristotle', 'a keen systematic collector', 'keen|systematic', 'NOUN', 'Aristotle', 985)
# ('result', 'of', "of the fact that the female body is well-suited for reproduction, which changes her body temperature, which in turn makes her, in Aristotle's view, incapable of participating in political life", None, None, 'NOUN', 'Aristotle', 986)
# ('proponents', 'of', 'of feminist metaphysics', None, None, 'NOUN', 'Aristotle', 987)
# ('describe', 'v2np', "\nAristotle's analysis of procreation describes an active, ensouling masculine element bringing life to an inert, passive female element.", "\nAristotle's analysis of procreation", 'active', 'VERB', 'Aristotle', 988)
# ('accuse', 'v2np', 'On this ground, proponents of feminist metaphysics have accused Aristotle of misogyny and sexism.', 'proponents of feminist metaphysics', 'Aristotle', 'VERB', 'Aristotle', 989)
# ('give', 'v2np', "However, Aristotle gave equal weight to women's happiness as he did to men's, and commented in his Rhetoric that the things that lead to happiness need to be in women as well as men.", 'Aristotle', 'however|weight|comment', 'VERB', 'Aristotle', 990)

# %%
def query_db(target):
    cursor.execute("SELECT * FROM allusions WHERE target=?", (target,))
    rows = cursor.fetchall()
    return rows

query_db("remain")
# Out:
# [('remain',
#   'v2np',
#   'opposition to the Kansas–Nebraska Act remained strong throughout the North.',
#   'opposition to the Kansas–Nebraska Act',
#   None,
#   'VERB',
#   'Abraham Lincoln',
#   379),
#  ('remain',
#   'v2np',
#   'Secession sentiment was strong in Missouri and Maryland, but did not prevail; Kentucky remained neutral.',
#   'Kentucky',
#   None,
#   'VERB',
#   'Abraham Lincoln',
#   527),
#  ('remain',
#   'v2np',
#   "Aristotle's writings on motion remained influential until the Early Modern period.",
#   "Aristotle's writings on motion",
#   None,
#   'VERB',
#   'Aristotle',
#   871)]
